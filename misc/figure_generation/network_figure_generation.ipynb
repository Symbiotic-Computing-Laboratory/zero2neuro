# %% [markdown]
# # Documentation Figure Generation

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
import keras

#################################################################
# Default plotting parameters
FIGURESIZE=(10,6)
FONTSIZE=14

plt.rcParams['figure.figsize'] = FIGURESIZE
plt.rcParams['font.size'] = FONTSIZE

plt.rcParams['xtick.labelsize'] = FONTSIZE-2
plt.rcParams['ytick.labelsize'] = FONTSIZE-2

#################################################################
# Out:
# 2026-04-16 23:34:28.572736: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-16 23:34:28.822617: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-16 23:34:30.320628: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-16 23:34:31.318793: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776400472.112612  728218 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776400472.373930  728218 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776400474.448166  728218 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776400474.448203  728218 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776400474.448205  728218 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776400474.448206  728218 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-16 23:34:34.714351: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def generate_figure(x,
                    y,
                    xlabel='net input',
                    ylabel='activation',
                    fname=None):
    plt.plot(x,y)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

    if fname is not None:
